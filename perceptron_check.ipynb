# %%
from perceptron import *

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import datasets

def accuracy(y_true, y_pred):
    accuracy = np.sum(y_true == y_pred) / len(y_true)
    return accuracy

X, y = datasets.make_blobs(n_samples=150, n_features=2, centers=2, cluster_std=1.05, random_state=2)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

p = Perceptron(learning_rate=0.01, num_iterations=1000, activation_func=sigmoid)
p.fit(X_train, y_train)
predictions = p.predict(X_test)

print("Perceptron classification accuracy", accuracy(y_test, predictions))

cm = confusion_matrix(y_test, predictions)
print("Confusion Matrix:")
print(cm)
# Out:
# Perceptron classification accuracy 1.0
# Confusion Matrix:
# [[14  0]
#  [ 0 16]]
# Wartość funkcji kosztu w iteracji 0: 10.080266442273603
# Wartość funkcji kosztu w iteracji 1: 7.872812519661896
# Wartość funkcji kosztu w iteracji 2: 6.540378719333716
# Wartość funkcji kosztu w iteracji 3: 5.61085227361195
# Wartość funkcji kosztu w iteracji 4: 4.897053934134309
# Wartość funkcji kosztu w iteracji 5: 4.320371174630511
# Wartość funkcji kosztu w iteracji 6: 3.840688070784109
# Wartość funkcji kosztu w iteracji 7: 3.4344076129848697
# Wartość funkcji kosztu w iteracji 8: 3.086119060017587
# Wartość funkcji kosztu w iteracji 9: 2.784963851835395
# Wartość funkcji kosztu w iteracji 10: 2.5228629596666523
# Wartość funkcji kosztu w iteracji 11: 2.29356637746552
# Wartość funkcji kosztu w iteracji 12: 2.092100445531586
# Wartość funkcji kosztu w iteracji 13: 1.914423848246379
# Wartość funkcji kosztu w iteracji 14: 1.757201161306859
# ...

# %%
from mlxtend.plotting import plot_decision_regions
plt.figure(figsize=(10, 6))
plot_decision_regions(X_train, y_train, clf=p, legend=2)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Decision Regions for Perceptron')
# Out:
# Text(0.5, 1.0, 'Decision Regions for Perceptron')

# %%
plt.plot(list(range(p.num_iterations)), p.costs)
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.title('Error by iteration')
# Out:
# Text(0.5, 1.0, 'Error by iteration')
