# %%
from sklearn import datasets
import pandas as pd 
import numpy as np
iris = datasets.load_iris(as_frame=True)

# %% [markdown]
# ## IRIS DATASET

# %%
data1 = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])

# %%
data1
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0       0.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(iris['data'])
X = sc.transform(iris['data'])
X
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
x_reduced = pca.fit_transform(X)

# %%
plt.scatter(
    x_reduced[:, 0],
    x_reduced[:, 1],
    c=iris.target,
    s=40
)
plt.title('Pierwsze dwie PCA- iris datset')
plt.xlabel('1st PCA')
plt.ylabel('2nd PCA')
# Out:
# Text(0, 0.5, '2nd PCA')

# %% [markdown]
# ## WINE DATASET

# %%
from sklearn.datasets import load_wine
wine = load_wine(as_frame=True)
data2 = pd.DataFrame(data= np.c_[wine['data'], wine['target']],
                     columns= wine['feature_names'] + ['target'])
data2
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
sc2 = StandardScaler()
X2 = sc.fit_transform(wine['data'])

pca2 = PCA(n_components=2)
x_reduced2 = pca2.fit_transform(X2)

plt.figure()
plt.scatter(x_reduced2[:, 0], x_reduced2[:, 1], c=wine.target, cmap='viridis', s=40)
plt.title('Pierwsze dwie składowe główne (PCA) - zbiór danych Wine')
plt.xlabel('Pierwsza składowa główna (PCA)')
plt.ylabel('Druga składowa główna (PCA)')
plt.colorbar(label='Target')
plt.show()

# %% [markdown]
# ## DIABETS DATASET

# %%
from sklearn.datasets import load_diabetes
diabets = load_diabetes(as_frame=True)
data3 = pd.DataFrame(data= np.c_[diabets['data'], diabets['target']],
                     columns= diabets['feature_names'] + ['target'])
data3
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
sc3 = StandardScaler()
X3 = sc.fit_transform(diabets['data'])

pca3 = PCA(n_components=2)
x_reduced3 = pca3.fit_transform(X3)

plt.figure()
plt.scatter(x_reduced3[:, 0], x_reduced3[:, 1], c=diabets.target, cmap='viridis', s=40)
plt.title('Pierwsze dwie składowe główne (PCA) - zbiór danych Diabetes')
plt.xlabel('Pierwsza składowa główna (PCA)')
plt.ylabel('Druga składowa główna (PCA)')
plt.colorbar(label='Target')
plt.show()

# %% [markdown]
# # ZADANIE 2

# %%
from sklearn.datasets import fetch_california_housing
california = fetch_california_housing(as_frame=True)
data4 = pd.DataFrame(data= np.c_[california['data'], california['target']],
                     columns= california['feature_names'] + ['target'])
data4
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target
# ...

# %%
plt.hist(data4['target'])
# Out:
# (array([ 877., 3612., 4099., 3771., 2799., 1769., 1239.,  752.,  479.,
#         1243.]),
#  array([0.14999 , 0.634992, 1.119994, 1.604996, 2.089998, 2.575   ,
#         3.060002, 3.545004, 4.030006, 4.515008, 5.00001 ]),
#  <BarContainer object of 10 artists>)

# %%
sc4 = StandardScaler()
X4 = sc.fit_transform(california['data'])

pca4 = PCA(n_components=2)
x_reduced4 = pca4.fit_transform(X4)

# Podział cen domów na kategorie
low_price = california.target < 2
medium_price = (california.target >= 2) & (california.target < 4)
high_price = california.target >= 4

# Wykres
plt.scatter(
    x_reduced4[low_price, 0],
    x_reduced4[low_price, 1],
    c='blue',
    s=40,
    label='Niskie ceny'
)

plt.scatter(
    x_reduced4[medium_price, 0],
    x_reduced4[medium_price, 1],
    c='green',
    s=40,
    label='Średnie ceny'
)

plt.scatter(
    x_reduced4[high_price, 0],
    x_reduced4[high_price, 1],
    c='red',
    s=40,
    label='Wysokie ceny'
)

# Dodanie legendy
plt.legend()

plt.title('Pierwsze dwie PCA - california dataset')
plt.xlabel('1st PCA')
plt.ylabel('2nd PCA')
plt.show()

# %% [markdown]
# # ZADANIE 3

# %%
dane6 = pd.read_csv('C:\\Users\\HP\\Downloads\\autentykacja_eeg.csv', sep=';')
dane6.head()
# Out:
#     Delta   Theta  Alpha_low  Alpha_high  Beta_low  Beta_high  Gamma_low  \
# 0  785389  114375      57106       37625     24464      17104      15846
# 1  386949   80792      23506       22118      9566       7147       5392
# 2   21453   14085       4756        5062      2176       2117       2867
# 3  322637   56936      17810       25793     15870       8050       3621
# 4   19412   12985       6416        6131      7126       7419       2677
#
#    Gamma_high  Attention  Meditation  BlinkStrength  Flag
# 0        8024         45          91             15     1
# 1        1697          8          42              6     0
# 2         862         48          66              9     1
# 3        2100         25          69              8     0
# 4        1884         80          53             -1     1

# %%
x6 = dane6.drop('Flag', axis = 1)
y6 = dane6['Flag']
sc6 = StandardScaler()
x6_sc = sc6.fit_transform(x6)
pca6 = PCA(n_components=2)
x_reduced6 = pca6.fit_transform(x6_sc)
classes = np.unique(y6)

colors = plt.cm.rainbow(np.linspace(0, 1, len(classes)))

for i, class_label in enumerate(classes):
    plt.scatter(x_reduced6[y6 == class_label, 0], x_reduced6[y6 == class_label, 1], color=colors[i], label=str(class_label))

plt.title('PCA Dataset (2D)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Class')
plt.show()

# %% [markdown]
# ## LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

target_names = iris.target_names
y = iris['target']
X = iris['data']
sc3 = StandardScaler()
X = sc3.fit_transform(X)
lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit(X, y).transform(X)

plt.figure()
colors = ['navy', 'turquoise', 'darkorange']
lw = 2

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_lda[y == i, 0], X_lda[y == i, 1], color=color, alpha=.8, lw=lw,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('LDA of IRIS dataset')

plt.show()

# %%
wine = load_wine()
X = wine.data
y = wine.target
target_names = wine.target_names

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit(X_scaled, y).transform(X_scaled)

plt.figure()
colors = ['navy', 'turquoise', 'darkorange']
lw = 2

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_lda[y == i, 0], X_lda[y == i, 1], color=color, alpha=.8, lw=lw,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('LDA of wine dataset')

plt.show()

# %%
X = diabets.data
y = diabets.target

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit(X_scaled, y).transform(X_scaled)

plt.figure()
plt.scatter(X_lda[:, 0], X_lda[:, 1], c=y, cmap='viridis', alpha=0.8)
plt.xlabel('LD 1')
plt.ylabel('LD 2')
plt.title('LDA of Diabetes dataset')
plt.colorbar(label='Target')
plt.show()

# %%
california = fetch_california_housing()
X = california.data
y = california.target

# Podział cen domów na kategorie
low_price = y < 2
medium_price = (y >= 2) & (y < 4)
high_price = y >= 4

# Standaryzacja danych
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Nowe etykiety
new_y = np.zeros_like(y)
new_y[low_price] = 0
new_y[medium_price] = 1
new_y[high_price] = 2

# Redukcja wymiarowości za pomocą LDA
lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit(X_scaled, new_y).transform(X_scaled)

# Wykres LDA z kolorowaniem na podstawie kategorii cen
plt.figure()
plt.scatter(X_lda[new_y == 0, 0], X_lda[new_y == 0, 1], c='blue', s=40, label='Niskie ceny')
plt.scatter(X_lda[new_y == 1, 0], X_lda[new_y == 1, 1], c='green', s=40, label='Średnie ceny')
plt.scatter(X_lda[new_y == 2, 0], X_lda[new_y == 2, 1], c='red', s=40, label='Wysokie ceny')

# Dodanie legendy
plt.legend()

plt.title('LDA of California Housing dataset')
plt.xlabel('First LDA component')
plt.ylabel('Second LDA component')
plt.show()

# %% [markdown]
# # ZADANIE 4

# %%
from sklearn.datasets import load_iris

# Załaduj dane
iris = load_iris()
wine = load_wine()
diabetes = load_diabetes()
california = fetch_california_housing()

# Standaryzacja danych
scaler = StandardScaler()
X_iris = scaler.fit_transform(iris.data)
X_wine = scaler.fit_transform(wine.data)
X_diabetes = scaler.fit_transform(diabetes.data)
X_california = scaler.fit_transform(california.data)

# Obliczenie SVD i redukcja wymiarów dla każdego zbioru
U_iris, S_iris, Vt_iris = np.linalg.svd(X_iris)
U_wine, S_wine, Vt_wine = np.linalg.svd(X_wine)
U_diabetes, S_diabetes, Vt_diabetes = np.linalg.svd(X_diabetes)
U_california, S_california, Vt_california = np.linalg.svd(X_california)

# Redukcja wymiarów (wybierz k składowych)
k = 2
X_iris_reduced = np.dot(X_iris, Vt_iris[:k].T)
X_wine_reduced = np.dot(X_wine, Vt_wine[:k].T)
X_diabetes_reduced = np.dot(X_diabetes, Vt_diabetes[:k].T)
X_california_reduced = np.dot(X_california, Vt_california[:k].T)

# Wykresy dla każdego zbioru danych po redukcji wymiarów
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
plt.scatter(X_iris_reduced[:, 0], X_iris_reduced[:, 1], c=iris.target)
plt.title('Iris dataset - SVD reduction')
plt.xlabel('Component 1')
plt.ylabel('Component 2')

plt.subplot(2, 2, 2)
plt.scatter(X_wine_reduced[:, 0], X_wine_reduced[:, 1], c=wine.target)
plt.title('Wine dataset - SVD reduction')
plt.xlabel('Component 1')
plt.ylabel('Component 2')

plt.subplot(2, 2, 3)
plt.scatter(X_diabetes_reduced[:, 0], X_diabetes_reduced[:, 1], c=diabetes.target)
plt.title('Diabetes dataset - SVD reduction')
plt.xlabel('Component 1')
plt.ylabel('Component 2')

plt.subplot(2, 2, 4)
plt.scatter(X_california_reduced[:, 0], X_california_reduced[:, 1], c=california.target)
plt.title('California dataset - SVD reduction')
plt.xlabel('Component 1')
plt.ylabel('Component 2')

plt.tight_layout()
plt.show()
